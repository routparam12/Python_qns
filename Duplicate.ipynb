# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Python_qns/blob/main/Duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,3,4,2,2]
duplicate=[]
seen=[]

for i in nums:
  if i in seen:
    duplicate.append(i)
  else:
    seen.append(i)
print(seen)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Linear search

# %%
def Linear_search(nums, target):
  for i in nums:
    if i == target:
      return nums.index(i)
  return -1

Linear_search([3,6,9,1], 9)
# Out:
# 2

# %%
def linear_search(nums, target):
    for i, value in enumerate(nums):
        if value == target:
            return i
    return -1

linear_search([3,8,5],95)
# Out:
# -1

# %%
def bubble_sort(nums):
    n = len(nums)

    for i in range(n):
        for j in range(0, n - i - 1):
            if nums[j] > nums[j + 1]:
                nums[j], nums[j + 1] = nums[j + 1], nums[j]

    return nums

bubble_sort([3,8,5,95,43])
# Out:
# [3, 5, 8, 43, 95]

# %% [markdown]
# Start
# [5, 2, 8, 1, 3]
#
# Pass 1
# [2, 5, 1, 3, 8]
#              ↑
#           largest fixed
#
# Pass 2
# [2, 1, 3, 5, 8]
#           ↑
#        next fixed
#
# Pass 3
# [1, 2, 3, 5, 8]
#        ↑
#     sorted

# %%
def selection_sort(nums):
    n = len(nums)

    for i in range(n):
        min_index = i

        for j in range(i + 1, n):
            if nums[j] < nums[min_index]:
                min_index = j

        nums[i], nums[min_index] = nums[min_index], nums[i]

    return nums
selection_sort([3,8,5,95,43])
# Out:
# [3, 5, 8, 43, 95]

# %% [markdown]
# Start
# [5, 2, 8, 1, 3]
#
# Find minimum = 1
# [1 | 2, 8, 5, 3]
#
# Find minimum = 2
# [1, 2 | 8, 5, 3]
#
# Find minimum = 3
# [1, 2, 3 | 5, 8]
#
# Find minimum = 5
# [1, 2, 3, 5 | 8]
#
# Sorted ✅
# [1, 2, 3, 5, 8]
