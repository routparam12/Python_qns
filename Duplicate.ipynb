# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Python_qns/blob/main/Duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,3,4,2,2]
duplicate=[]
seen=[]

for i in nums:
  if i in seen:
    duplicate.append(i)
  else:
    seen.append(i)
print(seen)
# Out:
# [1, 2, 3, 4]

# %%
nums =
