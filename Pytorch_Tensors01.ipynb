# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Python_qns/blob/main/Pytorch_Tensors01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
if torch.cuda.is_available():
    print("cuda is available")
    print(torch.cuda.get_device_name(0))
else:
    print("cuda is not available")
# Out:
# cuda is available
# Tesla T4

# %% [markdown]
# Creating a Tensor

# %%
#uning Empty
a = torch.empty(2,3)
# returns the value already existing in the empty space

# %%
#check type
type(a)
# Out:
# torch.Tensor
