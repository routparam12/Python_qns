# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Python_qns/blob/main/pytorch-nn-module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create model class
import torch
import torch.nn as nn

class Model(nn.Module):

  def __init__(self, num_features):

    super().__init__()
    self.network = nn.Sequential(
        nn.Linear(num_features, 3),
        nn.ReLU(),
        nn.Linear(3, 1),
        nn.Sigmoid()
    )

  def forward(self, features):

    out = self.network(features)

    return out

# %%
# create dataset
features = torch.rand(10,5)

# create model
model = Model(features.shape[1])

# call model for forward pass
# model.forward(features)
model(features)
# Out:
# tensor([[0.5783],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5593],
#         [0.5820]], grad_fn=<SigmoidBackward0>)

# %%
# show model weights
model.linear2.weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1777/1714805773.py in <cell line: 0>()
#       1 # show model weights
# ----> 2 model.linear2.weight
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1966             if name in modules:
#    1967                 return modules[name]
# -> 1968         raise AttributeError(
#    1969             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970         )
#
# AttributeError: 'Model' object has no attribute 'linear2'

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

summary(model, input_size=(10, 5))
